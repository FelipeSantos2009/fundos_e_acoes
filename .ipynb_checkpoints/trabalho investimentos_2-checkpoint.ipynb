# %%
import pandas as pd
import pyautogui as py
from time import sleep as sl

df = pd.read_excel('projeto_bi_2.xlsx')
display(df)
# Out:
#      AÇÕES
# 0    ARML3
# 1    ARZZ3
# 2    ASAI3
# 3    ATMP3
# 4    ATOM3
# ..     ...
# 566  WHRL3
# 567  WHRL4
# 568  WLMM3
# 569  WLMM4
# 570  YDUQ3
#
# [571 rows x 1 columns]

# %%
py.PAUSE = 0.3
py.press('win') 
py.write('excel') 
py.press('enter') 
sl(2) 
py.hotkey('ctrl', 'n') 
py.press('enter') 
py.press('enter') 
py.keyDown('win') 
py.press('down') 
py.keyUp('win') 
py.keyDown('win') 
py.press('down') 
py.keyUp('win') 
py.hotkey('ctrl', 't') 
py.write('https://statusinvest.com.br/') 
py.press('enter')
sl(3)
#PATRIMÔNIO LIQUIDO, lucro 
#pegar liquidez média diária, p/vp, CAGR LUCRO 5a, PATRIMÔNIO LIQUIDO, CAIXA, lucro 
#cont = 0 
for c in df['AÇÕES']:
    #cont += 1
    py.click(x=417, y=106)
    sl(0.7)
    py.write(c)
    sl(3.7)
    py.click(x=502, y=188)
    sl(0.7)
    #liquidez média diária
    py.scroll(-1200)
    py.leftClick(x=601, y=462)
    py.keyDown('shift')
    py.leftClick(x=772, y=460)
    py.keyUp('shift')
    py.hotkey('ctrl', 'c')
    py.click(x=1109, y=746)
    py.write(c)
    py.write(' ')
    py.hotkey('ctrl', 'v')
    py.press('right')
    py.keyDown('win') 
    py.press('down')
    py.press('down') 
    py.keyUp('win')
    py.click(x=1307, y=456)
    
    #p/vp
    py.scroll(-700)
    py.leftClick(x=675, y=203)
    py.keyDown('shift')
    py.leftClick(x=718, y=199)
    py.keyUp('shift')
    py.hotkey('ctrl', 'c')
    py.click(x=1101, y=744)
    py.keyDown('win')
    py.press('up')
    py.keyUp('win')
    py.hotkey('ctrl', 'v')
    py.press('right')
    py.keyDown('win') 
    py.press('down')
    py.press('down') 
    py.keyUp('win')
    
    #cagr lucro 5a
    py.leftClick(x=1047, y=526)
    py.keyDown('shift')
    py.leftClick(x=1124, y=523)
    py.keyUp('shift')
    py.hotkey('ctrl', 'c')
    py.click(x=1101, y=744)
    py.keyDown('win')
    py.press('up')
    py.keyUp('win')
    py.hotkey('ctrl', 'v')
    py.press('right')
    py.keyDown('win') 
    py.press('down')
    py.press('down') 
    py.keyUp('win')
    
    
    #patrimônio líquido
    py.click(x=276, y=146)
    #py.click(x=277, y=316)
    sl(0.8)
    py.leftClick(x=226, y=465)
    py.keyDown('shift')
    py.leftClick(x=388, y=464)
    py.keyUp('shift')
    py.hotkey('ctrl', 'c')
    py.click(x=1101, y=744)
    py.keyDown('win')
    py.press('up')
    py.keyUp('win')
    py.hotkey('ctrl', 'v')
    py.press('right')
    py.keyDown('win') 
    py.press('down')
    py.press('down') 
    py.keyUp('win')
    
    #caixa
    py.scroll(-500)
    sl(0.8)
    py.click(x=407, y=141)
    sl(0.8)
    py.scroll(-700)
    sl(0.8)
    py.leftClick(x=453, y=263)
    py.keyDown('shift')
    py.leftClick(x=535, y=266)
    py.keyUp('shift')
    py.hotkey('ctrl', 'c')
    py.click(x=1101, y=744)
    py.keyDown('win')
    py.press('up')
    py.keyUp('win')
    py.hotkey('ctrl', 'v')
    py.press('right')
    py.keyDown('win') 
    py.press('down')
    py.press('down') 
    py.keyUp('win')
    
    #lucro
    py.leftClick(x=457, y=339)
    py.keyDown('shift')
    py.leftClick(x=534, y=337)
    py.keyUp('shift')
    py.hotkey('ctrl', 'c')
    py.click(x=1101, y=744)
    py.keyDown('win')
    py.press('up')
    py.keyUp('win')
    py.hotkey('ctrl', 'v')
    py.press('down')
    py.press('left')
    py.press('left')
    py.press('left')
    py.press('left')
    py.press('left')
    py.keyDown('win') 
    py.press('down')
    py.press('down') 
    py.keyUp('win')
    
    py.click(x=417, y=106)
    py.hotkey('ctrl', 'a')
    py.press('delete')
    #if cont == 2:
        #break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-bf92a2fd2133> in <module>
#      97     py.hotkey('ctrl', 'v')
#      98     py.press('right')
# ---> 99     py.keyDown('win')
#     100     py.press('down')
#     101     py.press('down')
#
# ~\anaconda3\lib\site-packages\pyautogui\__init__.py in wrapper(*args, **kwargs)
#     597         failSafeCheck()
#     598         returnVal = wrappedFunction(*args, **kwargs)
# --> 599         _handlePause(kwargs.get("_pause", True))
#     600         return returnVal
#     601
#
# ~\anaconda3\lib\site-packages\pyautogui\__init__.py in _handlePause(_pause)
#     641     if _pause:
#     642         assert isinstance(PAUSE, int) or isinstance(PAUSE, float)
# --> 643         time.sleep(PAUSE)
#     644
#     645
#
# KeyboardInterrupt:

# %%
sl(4)
py.position()
# Out:
# Point(x=534, y=337)

# %%
sl(3)
py.scroll(-1300)

# %%
#sl(3)
#py.scroll(-1800)
#py.leftClick(x=676, y=437)
#py.keyDown('shift')
#py.leftClick(x=716, y=435)
#py.keyUp('shift')
#py.hotkey('ctrl', 'c')
