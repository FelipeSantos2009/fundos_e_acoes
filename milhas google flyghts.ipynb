# %%
import pandas as pd
from time import sleep as sl
from selenium import webdriver
import pyautogui as py

#buscar valor do trecho no gogle flights e comparar com o balcão de milhas
df = pd.read_excel('Sua próxima viagem(1-2) (1).xlsx')
display(df)
# Out:
#    ID      Hora de início   Hora de conclusão      Email  Nome  \
# 0   4 2023-03-31 19:46:25 2023-03-31 19:47:46  anonymous   NaN
# 1   5 2023-03-31 19:47:52 2023-03-31 19:49:02  anonymous   NaN
#
#    Total de pontos  Comentários do teste  \
# 0              NaN                   NaN
# 1              NaN                   NaN
#
#    Qual o seu telefone? (inserir DDD e/ou DDI)  \
# 0                                  19922022335
# 1                                  19992080618
#
#    Pontos – Qual o seu telefone? (inserir DDD e/ou DDI)  \
# 0                                                NaN
# 1                                                NaN
#
#    Comentários – Qual o seu telefone? (inserir DDD e/ou DDI)  ...  \
# 0                                                NaN          ...
# 1                                                NaN          ...
#
#   Comentários – Qual o seu destino?  \
# 0                               NaN
# 1                               NaN
#
# ...

# %%
#manter somente colunas que importa para a gente
df.drop(columns=['Hora de início', 'Email', 'Pontos – Qual o seu telefone? (inserir DDD e/ou DDI)', 'Comentários – Qual o seu telefone? (inserir DDD e/ou DDI)', 'Pontos – Qual o seu nome?', 'Comentários – Qual o seu nome?', 'Nome', 'Total de pontos', 'Comentários do teste', 'Pontos – Qual a sua origem?', 'Comentários – Qual a sua origem?', 'Pontos – Qual a data aproximada de embarque? (partida)', 'Comentários – Qual a data aproximada de embarque? (partida)', 'Pontos – Qual o seu destino?', 'Comentários – Qual o seu destino?', 'Pontos – Qual a data de retorno?', 'Comentários – Qual a data de retorno?', 'Pontos – Deseja inserir algum comentário adicional ?(opcional)', 'Comentários – Deseja inserir algum comentário adicional ?(opcional)'])
# Out:
#    ID   Hora de conclusão  Qual o seu telefone? (inserir DDD e/ou DDI)  \
# 0   4 2023-03-31 19:47:46                                  19922022335
# 1   5 2023-03-31 19:49:02                                  19992080618
#
#      Qual o seu nome? Qual a sua origem? Qual o seu destino?  \
# 0    Elysiario Santos           Campinas               Dubai
# 1  Elisabete Virginia              Miami             Orlando
#
#   Qual a data aproximada de embarque? (partida) Qual a data de retorno?  \
# 0                                      01032024                03042024
# 1                                      01/03/24                 15/3/24
#
#   Deseja inserir algum comentário adicional ?(opcional)
# 0                                      Bom trabalho!
# 1                 Brincadeira, dá pra ir de carrokkk

# %%
#print(df['Qual o seu destino?'][1])
#df['Qual a data aproximada de embarque? (partida)']
embarque = []
embarque.append(df['Qual a sua origem?'][1])
display(embarque)
#print(df['Qual a data de retorno?'])
# Out:
# ['Miami']

# %%
navegador = webdriver.Chrome()
navegador.get('https://www.google.com')
link = 'https://www.google.com/travel/flights?hl=pt-BR'
navegador.get(link)
print(link)
sl(1)
py.keyDown('win')
sl(0.2)
py.press('up')
sl(0.2)
py.keyUp('win')
sl(1)
navegador.find_element('xpath', '//*[@id="i15"]/div[1]/div/div/div[1]/div/div/input').click()
sl(1)
navegador.find_element('xpath', '//*[@id="i15"]/div[6]/div[2]/div[2]/div[1]/div/input').send_keys(df['Qual a sua origem?'][1])
py.press('enter')
sl(1)
py.click(x=709, y=586)
navegador.find_element('xpath', '//*[@id="i15"]/div[6]/div[2]/div[2]/div[1]/div/input').send_keys(df['Qual o seu destino?'][1])
py.press('enter')
navegador.find_element('xpath', '//*[@id="yDmH0d"]/c-wiz[2]/div/div[2]/c-wiz/div[1]/c-wiz/div[2]/div[1]/div[1]/div[1]/div/div[2]/div[2]/div/div/div[1]/div/div/div[1]/div/div[1]/div/input').click()
sl(1)
py.write(df['Qual a data aproximada de embarque? (partida)'][1])
sl(1)
py.press('enter')
navegador.find_element('xpath', '//*[@id="ow75"]/div[2]/div/div[2]/div[1]/div[1]/div[2]/div/input').send_keys(df['Qual a data de retorno?'][1])
sl(1)
py.click(x=890, y=185)
sl(0.5)
py.click(x=890, y=185)
sl(1)
py.hotkey('ctrl', 'a')
sl(1)
py.press('delete')
navegador.find_element('xpath', '//*[@id="ow75"]/div[2]/div/div[2]/div[1]/div[1]/div[1]/div/input').send_keys(df['Qual a data aproximada de embarque? (partida)'][1])
py.press('enter')

#primeiro dia do mês
#//*[@id="ow68"]/div[2]/div/div[2]/div[2]/div/div/div[1]/div/div[11]/div[3]/div[1]/div[1]/div[2]
#segundo dia do mês
#//*[@id="ow68"]/div[2]/div/div[2]/div[2]/div/div/div[1]/div/div[11]/div[3]/div[1]/div[2]/div
#terceiro dia do mês
#//*[@id="ow68"]/div[2]/div/div[2]/div[2]/div/div/div[1]/div/div[11]/div[3]/div[1]/div[3]/div
#quarto dia do mês
#//*[@id="ow68"]/div[2]/div/div[2]/div[2]/div/div/div[1]/div/div[11]/div[3]/div[2]/div[1]/div

# %%
# selecionar data de volta
#google flights usa o calendário em estilo americano, então ele inverte os dias e os meses
sl(3)
py.click(x=1052, y=187)
sl(0.5)
py.click(x=1052, y=187)
sl(1)
py.hotkey('ctrl', 'a')
sl(1)
py.press('delete')
navegador.find_element('xpath', '//*[@id="ow75"]/div[2]/div/div[2]/div[1]/div[1]/div[2]/div/input').send_keys('02/03/24')
#essa data é usada como exemplo
py.press('enter')
sl(1)
py.click(x=1098, y=690)
sl(1)
py.click(x=685, y=655)
sl(3)
py.scroll(-300)
sl(1)
py.leftClick(x=119, y=351)
py.keyDown('shift')
py.leftClick(x=1226, y=592)
py.click(x=1220, y=600)
py.keyUp('shift')
sl(0.5)
py.hotkey('ctrl', 'c')
sl(0.5)

# %%
#colar no excel
py.press('win')
sl(0.5)
py.write('excel')
sl(0.5)
py.press('enter')
sl(4)
py.keyDown('win')
py.press('up')
py.keyUp('win')
sl(1)
py.click(x=271, y=226)
sl(0.5)
py.click(x=271, y=226)
sl(0.5)
py.click(x=62, y=310)
sl(1.5)
py.hotkey('ctrl', 'v')

# %%
#buscar o valor do trecho na american airlines
navegador = webdriver.Chrome()
navegador.get('https://www.google.com')
link = 'https://www.aa.com.br/homePage.do?locale=pt_BR'
navegador.get(link)
print(link)
py.click(x=981, y=32)
sl(1)
py.click(x=942, y=651)
sl(1)
py.scroll(-400)
sl(1)
navegador.find_element('xpath', '//*[@id="bookingCheckboxContainer"]/div[2]/div/label/span').click()
navegador.find_element('xpath', '//*[@id="reservationFlightSearchForm.destinationAirport"]').click()
navegador.find_element('xpath', '//*[@id="reservationFlightSearchForm.destinationAirport"]').send_keys(df['Qual o seu destino?'][1])
sl(0.5)
py.click(x=769, y=450)
sl(0.2)
py.click(x=771, y=440)
navegador.find_element('xpath', '//*[@id="aa-leavingOn"]').click()
navegador.find_element('xpath', '//*[@id="aa-leavingOn"]').send_keys('01/12/23')
navegador.find_element('xpath', '//*[@id="aa-returningFrom"]').click()
navegador.find_element('xpath', '//*[@id="aa-returningFrom"]').send_keys('01/01/24')
navegador.find_element('xpath', '//*[@id="flightSearchForm.button.reSubmit"]').click()
sl(35)
#data usadas somente como um teste

py.scroll(-2600)
sl(1)
navegador.find_element('xpath', '//*[@id="flightSearchSubmitBtn"]').click()

sl(20)

py.scroll(-200)
sl(1)
navegador.find_element('xpath', '//*[@id="flight0-product0"]').click()
sl(9)
py.scroll(-700)
sl(1)
navegador.find_element('xpath', '//*[@id="flight0-product0"]').click()
sl(9)
py.leftClick(x=177, y=525)
py.keyDown('shift')
py.leftClick(x=363, y=580)
py.click(x=370, y=590)
py.keyUp('shift')
sl(0.5)
py.hotkey('ctrl', 'c')
sl(0.5)

# %%
#colar no bloco de notas

py.press('win')
sl(1)
py.write('bloco de notas')
sl(1)
py.press('enter')
sl(1)
py.hotkey('ctrl', 'v')
sl(1)
py.hotkey('ctrl', 'a')
sl(1)
py.hotkey('ctrl', 'c')

# %%
#colar no excel

py.click(x=975, y=745)
sl(1)
py.click(x=252, y=315)
sl(1)
py.hotkey('ctrl', 'v')

# %%
#1-)entrar no site das 4 companhias (smiles, tap, latam e azul) e ver quantos pontos são necessários para os trechos que estão na planilha do forms

#azul
navegador = webdriver.Chrome()
navegador.get('https://www.google.com')
link = 'https://www.voeazul.com.br/br/pt/home'
navegador.get(link)
print(link)

sl(3)
navegador.find_element('xpath', '//*[@id="Origem1"]').send_keys(df['Qual a sua origem?'][1])
py.press('enter')
navegador.find_element('xpath', '//*[@id="Destino1"]').send_keys(df['Qual o seu destino?'][1])
py.press('enter')
navegador.find_element('xpath', '//*[@id="spa-root"]/main/div[1]/div[1]/div[1]/div[1]/div[3]/div[1]/div[1]/div[1]/div[1]/div/nav/div/div/div[1]/div[1]/div[1]/ul/li/div/div[1]/div/div[2]/label').click()
navegador.find_element('xpath', '//*[@id="departure-1"]').send_keys(df['Qual a data aproximada de embarque? (partida)'][1])
navegador.find_element('xpath', '//*[@id="return-1"]').send_keys(df['Qual a data de retorno?'][1])
py.scroll(-200)
navegador.find_element('xpath', '//*[@id="spa-root"]/main/div[1]/div[1]/div[1]/div[1]/div[3]/div[1]/div[1]/div[1]/div[1]/div/nav/div/div/div[1]/div[1]/div[1]/ul/li/div/div[1]/div/div[2]/div/div/div[4]/button').click()
navegador.find_element('xpath', '//*[@id="spa-root"]/main/div[1]/div[1]/div[1]/div[1]/div[3]/div[1]/div[1]/div[1]/div[1]/div/nav/div/div/div[1]/div[1]/div[3]/div[1]/div[2]/div/div[1]/ul/li[2]/button').click()
navegador.find_element('xpath', '//*[@id="spa-root"]/main/div[1]/div[1]/div[1]/div[1]/div[3]/div[1]/div[1]/div[1]/div[1]/div/nav/div/div/div[1]/div[1]/div[3]/div[3]/div/button').click()
# Out:
# https://www.voeazul.com.br/br/pt/home
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-4-abae55624bd3> in <module>
#      17 navegador.find_element('xpath', '//*[@id="return-1"]').send_keys(df['Qual a data de retorno?'][1])
#      18 py.scroll(-200)
# ---> 19 navegador.find_element('xpath', '//*[@id="spa-root"]/main/div[1]/div[1]/div[1]/div[1]/div[3]/div[1]/div[1]/div[1]/div[1]/div/nav/div/div/div[1]/div[1]/div[1]/ul/li/div/div[1]/div/div[2]/div/div/div[4]/button').click()
#      20 navegador.find_element('xpath', '//*[@id="spa-root"]/main/div[1]/div[1]/div[1]/div[1]/div[3]/div[1]/div[1]/div[1]/div[1]/div/nav/div/div/div[1]/div[1]/div[3]/div[1]/div[2]/div/div[1]/ul/li[2]/button').click()
# ...

# %%
#2-)multiplicar pelo preço médio das milhas que buscamos no balcão e acrescentar 25%

# %%
from time import sleep as sl
import pyautogui as py

sl(5)
py.position()

# %%
# teste tela cheia
#sl(4)
#py.keyDown('win')
#py.press('up')
#py.keyUp('win')
